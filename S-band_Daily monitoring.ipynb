# %%
from pathlib import Path
ap='m023'
output_dir=Path("./output/")
print(output_dir / Path(str('S-band daily monitoring '+ap+'.pdf')))
#fig.savefig(output_dir / Path('S-band daily monitoring '+ap+'.pdf'))
# Out:
# output/S-band daily monitoring m023.pdf

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import requests # Could use the builtin urllib but Requests are nicer.
from requests.exceptions import ConnectionError
import katpoint
import time
import pandas as pd
import csv
import re
import datetime

# %pylab inline
# %autosave 60
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Autosaving every 60 seconds

# %%
url="http://portal.mkat.karoo.kat.ac.za/katstore/api/query" # site for the most resent values
#url='http://kat-flap-cpt.mkat.control.kat.ac.za/katstore/samples' # flap in CT for older values

# %%
sensors = [
#    'rsc_rxl_state',
    ('anc_weather_temperature', 50,'gt'),
    #('rsc_rsc_he_compressor_supply_pressure', 18,'lt'),
    #('rsc_rsc_he_compressor_temperature1', 60,'gt'),
    ('rsc_rxs_tempvac_temp15k', 15,'gt'),
    ('rsc_rxs_tempvac_temp70k', 70,'gt'),
    ('rsc_rxs_cryocooler_motorspeedmeasure', 90,'lt'),
    ]

# %%
aps = []
for i in range(64):
    aps.append('m'+str(i).zfill(3))

# %%
now = time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime(time.time()))
def_start = katpoint.Timestamp(time.time()-1*24*3600)
def_end = katpoint.Timestamp(now)


all_data = {}        
for ap in aps:
    all_data[ap] = {}
    st =  time.time()
    len_rec = 0
    for i,sensor in enumerate(sensors): 
        sen = '%s_%s'%(ap,sensor[0]) if sensor[0].startswith('rsc') else '%s'%(sensor[0])  
        
        params={'sensor': sen,  # name of the sensor.
           'start_time':def_start.secs, # start time in seconds - float should work.
           'end_time': def_end.secs, # end time in seconds
           'limit':1000000,
           'include_value_time': True}
        for t in range(10):
            try:
                res = requests.get(url, params,timeout=200) # Make the call.
            except Exception as e:
                print (e)
                print ("Retrying")
                continue
            break
        res.close()
        if  res.status_code != 200: 
            continue
        len_rec += len(res.json()['data'])
        data_list = [(r['value_time'], r['value']) for r in res.json()['data']]
        data = array(data_list)
        #print(len(data))
        if len(data)!=0:
            err = any(data[:,1] >= sensor[1]) if sensor[2] == 'gt' else any(data[:,1] <= sensor[1])
            all_data[ap][sensor[0]] = {'ts':data[:,0],'data':data[:,1],'err':err}
    ed =  time.time()
    print ("%s processed in %.2f seconds with %d records at %s"%(ap,ed-st,len_rec,time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime(time.time()))))
# Out:
# m000 processed in 4.22 seconds with 13356 records at 2020-05-13 07:06:05
# m001 processed in 3.67 seconds with 8597 records at 2020-05-13 07:06:09
# m002 processed in 3.35 seconds with 12962 records at 2020-05-13 07:06:12
# m003 processed in 3.44 seconds with 13144 records at 2020-05-13 07:06:16
# m004 processed in 3.52 seconds with 13130 records at 2020-05-13 07:06:19
# m044 processed in 2.55 seconds with 8597 records at 2020-05-13 07:08:30
# m045 processed in 2.77 seconds with 9271 records at 2020-05-13 07:08:33
# m046 processed in 2.54 seconds with 8597 records at 2020-05-13 07:08:35
# m047 processed in 2.65 seconds with 8597 records at 2020-05-13 07:08:38
# m048 processed in 2.53 seconds with 8597 records at 2020-05-13 07:08:41
# m049 processed in 2.82 seconds with 9541 records at 2020-05-13 07:08:43
# m050 processed in 2.54 seconds with 8597 records at 2020-05-13 07:08:46
# m051 processed in 2.66 seconds with 8597 records at 2020-05-13 07:08:49
# m052 processed in 2.76 seconds with 8597 records at 2020-05-13 07:08:51
# m053 processed in 2.65 seconds with 9385 records at 2020-05-13 07:08:54
# m054 processed in 2.68 seconds with 8597 records at 2020-05-13 07:08:57
# m055 processed in 2.56 seconds with 8597 records at 2020-05-13 07:08:59
# m056 processed in 2.78 seconds with 9250 records at 2020-05-13 07:09:02
# m057 processed in 2.67 seconds with 9470 records at 2020-05-13 07:09:05
# m058 processed in 2.52 seconds with 8597 records at 2020-05-13 07:09:07
# m059 processed in 2.47 seconds with 8597 records at 2020-05-13 07:09:10
# m060 processed in 2.68 seconds with 9738 records at 2020-05-13 07:09:12
# m061 processed in 2.53 seconds with 8597 records at 2020-05-13 07:09:15
# m062 processed in 2.57 seconds with 8597 records at 2020-05-13 07:09:18
# m063 processed in 2.76 seconds with 8597 records at 2020-05-13 07:09:20

# %%
# Choose your xtick format string
#date_fmt = '%d-%m-%y\n%H:%M:%S'
date_fmt = '%d-%H:%M:%S'

# Use a DateFormatter to set the data to the correct format.
date_formatter = DateFormatter(date_fmt)
        
for ap in aps:
    err_state = []
    #for k in all_data[ap].iteritems():
    for k in all_data[ap].items():
        err_state.append(k[1]['err'])
    if any(err_state):
        fig=figure(figsize=(20,5))
        for i,sensor in enumerate(sensors): 
            sen = '%s_%s'%(ap,sensor[0]) if sensor[0].startswith('rsc') else '%s'%(sensor[0])
            subplot(1,4,i+1)
            try:
                ts = all_data[ap][sensor[0]]['ts']
                data = all_data[ap][sensor[0]]['data']
            except:
                continue
            plot_date(matplotlib.dates.epoch2num(ts),data)
            title('%s'%(sen))
            ax = gca()
            axhline(sensor[1],color='r',linewidth=3)
            ax.xaxis.set_major_formatter(date_formatter)#ax.figure.autofmt_xdate()
            ax.figure.autofmt_xdate()
            grid()
            fig.savefig(output_dir/ Path(str('S-band daily monitoring '+ap+'.pdf')))
    print (ap)
    
#fig.savefig('S-band daily monitoring')
# Out:
# m000
# m001
# m002
# m003
# m004
# m005
# m006
# m007
# m008
# m009
# m010
# m011
# m012
# m013
# m014
# m015
# m016
# m017
# m018
# m019
# m020
# m021
# m022
# m023
# m024
# m025
# m026
# m027
# m028
# m029
# m030
# m031
# m032
# m033
# m034
# m035
# m036
# m037
# m038
# m039
# m040
# m041
# m042
# m043
# m044
# m045
# m046
# m047
# m048
# m049
# m050
# m051
# m052
# m053
# m054
# m055
# m056
# m057
# m058
# m059
# m060
# m061
# m062
# m063

# %%
#fig.savefig('S-band daily monitoring: '+datetime.datetime.utcnow().strftime('%d,%b,%Y %H:%M:%S')+'.pdf')

# %%
aps = ['m005']

now = time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime(time.time()))
def_start = katpoint.Timestamp(time.time()-5*24*3600)
def_end = katpoint.Timestamp(now)

# %%
all_data = {}        
for ap in aps:
    all_data[ap] = {}
    st =  time.time()
    len_rec = 0
    for i,sensor in enumerate(sensors): 
        sen = '%s_%s'%(ap,sensor[0]) if sensor[0].startswith('rsc') else '%s'%(sensor[0])  
        
        params={'sensor': sen,  # name of the sensor.
           'start_time':def_start.secs, # start time in seconds - float should work.
           'end_time': def_end.secs, # end time in seconds
           'limit':1000000,
           'include_value_time': True}
        for t in range(10):
            try:
                res = requests.get(url, params,timeout=200) # Make the call.
            except Exception as e:
                print (e)
                print ("Retrying")
                continue
            break
        res.close()
        if  res.status_code != 200: 
            continue
        len_rec += len(res.json()['data'])
        data_list = [(r['value_time'], r['value']) for r in res.json()['data']]
        data = array(data_list)
        #print(len(data))
        if len(data)!=0:
            err = any(data[:,1] >= sensor[1]) if sensor[2] == 'gt' else any(data[:,1] <= sensor[1])
            all_data[ap][sensor[0]] = {'ts':data[:,0],'data':data[:,1],'err':err}
    ed =  time.time()
    print ("%s processed in %.2f seconds with %d records at %s"%(ap,ed-st,len_rec,time.strftime("%Y-%m-%d %H:%M:%S", time.gmtime(time.time()))))

# %%
# Choose your xtick format string
#date_fmt = '%d-%m-%y\n%H:%M:%S'
date_fmt = '%d-%H:%M:%S'

# Use a DateFormatter to set the data to the correct format.
date_formatter = DateFormatter(date_fmt)
        
for ap in aps:
    err_state = []
    #for k in all_data[ap].iteritems():
    for k in all_data[ap].items():
        err_state.append(k[1]['err'])
    if any(err_state):
        fig=figure(figsize=(20,5))
        for i,sensor in enumerate(sensors): 
            sen = '%s_%s'%(ap,sensor[0]) if sensor[0].startswith('rsc') else '%s'%(sensor[0])
            subplot(1,4,i+1)
            try:
                ts = all_data[ap][sensor[0]]['ts']
                data = all_data[ap][sensor[0]]['data']
            except:
                continue
            plot_date(matplotlib.dates.epoch2num(ts),data)
            title('%s'%(sen))
            ax = gca()
            axhline(sensor[1],color='r',linewidth=3)
            ax.xaxis.set_major_formatter(date_formatter)#ax.figure.autofmt_xdate()
            ax.figure.autofmt_xdate()
            grid()
            fig.savefig(output_dir/ Path(str('S-band daily monitoring2 '+ap+'.pdf')))
            
    print (ap)
    
#fig.savefig('S-band daily monitoring')
