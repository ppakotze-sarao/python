# %%
# %matplotlib notebook

# %%
from matplotlib import pyplot as plt

# %%
from rtlsdr import RtlSdr

sdr = RtlSdr()

# configure device
sdr.sample_rate = 2.048e6  # Hz
sdr.center_freq = 115.7e6     # Hz
sdr.freq_correction = 1   # PPM
sdr.gain = 4
samples=sdr.read_samples(512)
#print(samples)
print(type(samples[1]))
sdr.close()
plt.plot(np.abs
         (samples))
# Out:
# Found Fitipower FC0013 tuner
# <class 'numpy.complex128'>
# <img src="data:image/png;base64,..." width="640">

# %%
from pylab import *
from rtlsdr import *

sdr = RtlSdr()
serial_numbers = RtlSdr.get_device_serial_addresses()

# configure device
sdr.sample_rate = 300e3
#sdr.sample_rate = 1e6
sdr.center_freq = 115.7e6
sdr.gain = 'auto'

samples = sdr.read_samples(256*1024)
#samples = sdr.read_samples(16*1024)
sdr.close()

# use matplotlib to estimate and plot the PSD
figure(figsize=(16, 8), dpi=80)

psd(samples, NFFT=1024*16, Fs=sdr.sample_rate/1e6, Fc=sdr.center_freq/1e6)
xlabel('Frequency (MHz)')
ylabel('Relative power (dB)')

show()
# Out:
# Found Fitipower FC0013 tuner
# <img src="data:image/png;base64,..." width="1280">
