# %%
#using pandas to import a csv
#this is pps delays a file in kat config with delays in ns for each receptor
#on digitiser sync this gets loaded so that the digitiser knows how long it took the pps to reach it
#this gets all digitisers roughly in the same ballpark in terms of sync epoch
#the return journey suffers the same delay but in different fibre and tech (ethernet)
#the 

#this seems to be the number to use
refrac=4.765

import pandas as pd
df=pd.read_csv('/home/pkotze/checkouts/katconfig/user/delay-models/mkat/pps_delays.csv')
df.head()
# Out:
#   Receptor  Offset ns
# 0     m000      39570
# 1     m001      39570
# 2     m002      39590
# 3     m003      39570
# 4     m004      39930

# %%
#4.765is what Tony used in his example, not quite the physical numbers, 
#but it seems it is used elsewhere in reverse so have to stick to it

mkat_df=df[0:64]  #only get the MeerKat receptors
#print(mkat_df['Offset ns'].describe())

min_i=mkat_df['Offset ns'].idxmin()
max_i=mkat_df['Offset ns'].idxmax()
print(min_i) #index of minimum delay thus receptor (62)
print(mkat_df['Offset ns'][min_i]/refrac) #prints minimum delay / propagation thus length
print(mkat_df['Offset ns'][max_i]/refrac) #prints maximum delay / propagation thus length
print(max_i) #index of maximum delay thus receptor (57)

diff_length=[(mkat_df['Offset ns'][max_i] - delay) for delay in mkat_df['Offset ns'] ]
print((diff_length))  #prints difference in delay in ns from the shortest set to 0
# Out:
# 62
# 3563.4837355718787
# 12562.434417628543
# 57
# [20290, 20290, 20270, 20290, 19930, 20390, 20000, 20200, 27230, 18570, 27570, 18570, 18660, 17300, 17200, 16400, 16640, 16670, 16180, 18300, 18660, 19860, 20390, 20390, 19980, 20000, 21440, 20800, 21240, 21220, 15060, 15110, 14790, 8980, 14500, 15940, 16980, 16910, 27790, 27520, 27160, 15910, 15940, 19760, 18960, 24210, 12920, 16500, 490, 25450, 24410, 16180, 15990, 28350, 28490, 9200, 8440, 0, 9880, 19320, 24330, 25450, 42880, 28450]

# %%
#following line if you only want to do select receptors
receptors=['m001','m002','m003','m004','m005','m006','m007','m008','m011','m021','m030','m043','m045','m049','m057','m062']

#this bit generates all receptor names
aps = []
for i in range(64):
    aps.append('m'+str(i).zfill(3))
    
#only showing delay cal model for the following bands
bands=['l','u','s']
for receptor in receptors:
    print(receptor+'....====>')
    for band in bands:
        #print(receptor+'_'+band+'.txt')
        f=open('/home/pkotze/checkouts/katconfig/user/delay-models/mkat/'+receptor+'_'+band+'.txt')
        lines=f.readlines()
        '''
        f2=open('/home/pkotze/checkouts/katconfig/user/delay-models/mkat/'+receptor+'_s.csv')
        lines2=f2.readlines()
        f2.close()
        print(lines2)
        '''
        f.close()
        print(lines)
# Out:
# m001....====>
# ['1.1205 -171.762 8.4705 209.996 209.996 1\n']
# ['1.1205 -171.762 8.4705 211.133 211.133 1\n']
# ['1.1205 -171.762 8.4705 209.996 209.996 1\n']
# m002....====>
# ['-32.113 -224.236 8.6445 211.7145 211.7145 1\n']
# ['-32.113 -224.236 8.6445 210.0855 210.0855 1\n']
# ['-32.113 -224.236 8.6445 211.7145 211.7145 1\n']
# m003....====>
# ['-66.518 -202.276 8.285 213.4215 213.4215 1\n']
# ['-66.518 -202.276 8.285 210.8365 210.8365 1\n']
# ['-66.518 -202.276 8.285 213.4215 213.4215 1\n']
# m004....====>
# ['-123.624 -252.946 8.513 210.42 210.42 1\n']
# ['-123.624 -252.946 8.513 210.42 210.42 1\n']
# ['-123.624 -252.946 8.513 210.42 210.42 1\n']
# m005....====>
# ['-102.088 -283.12 8.875 217.998 217.998 1\n']
# ['-102.088 -283.12 8.875 217.998 217.998 1\n']
# ['-102.088 -283.12 8.875 217.998 217.998 1\n']
# m006....====>
# ['-18.2315 -295.428 9.188 220.4 220.4 1\n']
# ['-18.2315 -295.428 9.188 218.1725 218.1725 1\n']
# ['-18.2315 -295.428 9.188 220.4 220.4 1\n']
# m007....====>
# ['-89.592 -402.732 9.7685 205.53 205.53 1\n']
# ['-89.592 -402.732 9.7685 205.251 205.251 1\n']
# ['-89.592 -402.732 9.7685 205.53 205.53 1\n']
# m008....====>
# ['-93.527 -535.026 10.4445 215.5085 215.5085 1\n']
# ['-93.527 -535.026 10.4445 213.557 213.557 1\n']
# ['-93.527 -535.026 10.4445 215.5085 215.5085 1\n']
# m011....====>
# ['84.0115 -352.078 10.151 198.1045 198.1045 1\n']
# ['84.0115 -352.078 10.151 198.1045 198.1045 1\n']
# ['84.0115 -352.078 10.151 198.1045 198.1045 1\n']
# m021....====>
# ['-295.9655 -327.241 8.117 204.887 204.887 1\n']
# ['-295.9655 -327.241 8.117 204.018 204.018 1\n']
# ['-295.9655 -327.241 8.117 204.887 204.887 1\n']
# m030....====>
# ['171.2805 113.949 7.278 200.3155 200.3155 1\n']
# ['171.2805 113.949 7.278 200.3155 200.3155 1\n']
# ['171.2805 113.949 7.278 200.3155 200.3155 1\n']
# m043....====>
# ['-629.8525 -128.326 5.264 191.7415 191.7415 1\n']
# ['-629.8525 -128.326 5.264 200.978 200.978 1\n']
# ['-629.8525 -128.326 5.264 191.7415 191.7415 1\n']
# m045....====>
# ['-1832.8595 266.75 0.1075 213.253 213.253 1\n']
# ['-1832.8595 266.75 0.1075 206.351 206.351 1\n']
# ['-1832.8595 266.75 0.1075 213.253 213.253 1\n']
# m049....====>
# ['-3605.9565 436.462 2.696 217.607 217.607 1\n']
# ['-3605.9565 436.462 2.696 211.166 211.166 1\n']
# ['-3605.9565 436.462 2.696 217.607 217.607 1\n']
# m057....====>
# ['294.6445 3259.9145 -10.6365 189.3455 189.3455 1\n']
# ['294.6445 3259.9145 -10.6365 198.261 198.261 1\n']
# ['294.6445 3259.9145 -10.6365 189.3455 189.3455 1\n']
# m062....====>
# ['-1440.6315 -2503.773 21.6825 266.5405 266.5405 1\n']
# ['-1440.6315 -2503.773 21.6825 270.4365 270.4365 1\n']
# ['-1440.6315 -2503.773 21.6825 266.5405 266.5405 1\n']

# %%
#read delay cal result from manually created txt file
f=open('/home/pkotze/Downloads/delay_out_s.txt')

lines=f.readlines()
f.close()

x=[]
for line in lines:
    print(line)
    x+=line.split(' ')[9], float(line.split(':')[-1].split('ns')[0])
# Out:
# 2021-03-12 04:20:28.592Z INFO      - m001h:    -36.221 ns,    -63.39 samples
#
# 2021-03-12 04:20:28.592Z INFO      - m001v:    -36.228 ns,    -63.40 samples
#
# 2021-03-12 04:20:28.593Z INFO      - m002h:    -21.362 ns,    -37.38 samples
#
# 2021-03-12 04:20:28.593Z INFO      - m002v:    -21.360 ns,    -37.38 samples
#
# 2021-03-12 04:20:28.594Z INFO      - m003h:    -52.035 ns,    -91.06 samples
#
# 2021-03-12 04:20:28.594Z INFO      - m003v:    -52.055 ns,    -91.10 samples
#
# 2021-03-12 04:20:28.595Z INFO      - m004h:    -70.615 ns,   -123.58 samples
#
# 2021-03-12 04:20:28.596Z INFO      - m004v:    -70.658 ns,   -123.65 samples
#
# 2021-03-12 04:20:28.596Z INFO      - m005h:    -71.386 ns,   -124.92 samples
#
# 2021-03-12 04:20:28.597Z INFO      - m005v:    -71.436 ns,   -125.01 samples
#
# 2021-03-12 04:20:28.597Z INFO      - m006h:    -92.685 ns,   -162.20 samples
#
# 2021-03-12 04:20:28.600Z INFO      - m006v:    -92.771 ns,   -162.35 samples
#
# 2021-03-12 04:20:28.600Z INFO      - m007h:    -48.502 ns,    -84.88 samples
#
# 2021-03-12 04:20:28.601Z INFO      - m007v:    -48.178 ns,    -84.31 samples
#
# 2021-03-12 04:20:28.602Z INFO      - m008h:    -62.115 ns,   -108.70 samples
#
# 2021-03-12 04:20:28.602Z INFO      - m008v:    -61.877 ns,   -108.29 samples
#
# 2021-03-12 04:20:28.603Z INFO      - m009h:    -41.155 ns,    -72.02 samples
#
# 2021-03-12 04:20:28.603Z INFO      - m009v:    -41.190 ns,    -72.08 samples
#
# 2021-03-12 04:20:28.604Z INFO      - m010h:    -82.585 ns,   -144.52 samples
#
# 2021-03-12 04:20:28.604Z INFO      - m010v:    -82.658 ns,   -144.65 samples
#
# 2021-03-12 04:20:28.605Z INFO      - m011h:    -28.259 ns,    -49.45 samples
#
# 2021-03-12 04:20:28.605Z INFO      - m011v:    -28.345 ns,    -49.60 samples
#
# 2021-03-12 04:20:28.606Z INFO      - m012h:    -56.575 ns,    -99.01 samples
#
# 2021-03-12 04:20:28.607Z INFO      - m012v:    -56.454 ns,    -98.79 samples
#
# 2021-03-12 04:20:28.607Z INFO      - m013h:    -97.056 ns,   -169.85 samples
#
# 2021-03-12 04:20:28.608Z INFO      - m013v:    -96.960 ns,   -169.68 samples
#
# 2021-03-12 04:20:28.608Z INFO      - m014h:   -267.626 ns,   -468.35 samples
#
# 2021-03-12 04:20:28.609Z INFO      - m014v:   -267.660 ns,   -468.40 samples
#
# 2021-03-12 04:20:28.609Z INFO      - m017h:   -328.832 ns,   -575.46 samples
#
# 2021-03-12 04:20:28.610Z INFO      - m017v:   -328.852 ns,   -575.49 samples
#
# 2021-03-12 04:20:28.610Z INFO      - m018h:   1720.758 ns,   3011.33 samples
#
# 2021-03-12 04:20:28.611Z INFO      - m018v:   1092.792 ns,   1912.39 samples
#
# 2021-03-12 04:20:28.611Z INFO      - m019h:    -59.785 ns,   -104.62 samples
#
# 2021-03-12 04:20:28.612Z INFO      - m019v:    -59.798 ns,   -104.65 samples
#
# 2021-03-12 04:20:28.612Z INFO      - m020h:    -33.008 ns,    -57.76 samples
#
# 2021-03-12 04:20:28.613Z INFO      - m020v:    -33.054 ns,    -57.84 samples
#
# 2021-03-12 04:20:28.614Z INFO      - m021h:   -103.355 ns,   -180.87 samples
#
# 2021-03-12 04:20:28.614Z INFO      - m021v:   -103.448 ns,   -181.03 samples
#
# 2021-03-12 04:20:28.615Z INFO      - m022h:    -12.893 ns,    -22.56 samples
#
# 2021-03-12 04:20:28.615Z INFO      - m022v:    -12.944 ns,    -22.65 samples
#
# 2021-03-12 04:20:28.616Z INFO      - m023h:     -7.452 ns,    -13.04 samples
#
# 2021-03-12 04:20:28.616Z INFO      - m023v:     -7.440 ns,    -13.02 samples
#
# 2021-03-12 04:20:28.617Z INFO      - m027h:    -57.797 ns,   -101.14 samples
#
# 2021-03-12 04:20:28.617Z INFO      - m027v:    -57.737 ns,   -101.04 samples
#
# 2021-03-12 04:20:28.618Z INFO      - m030h:    -74.875 ns,   -131.03 samples
#
# 2021-03-12 04:20:28.619Z INFO      - m030v:    -74.824 ns,   -130.94 samples
#
# 2021-03-12 04:20:28.619Z INFO      - m032h:    -70.046 ns,   -122.58 samples
#
# 2021-03-12 04:20:28.620Z INFO      - m032v:    -70.008 ns,   -122.51 samples
#
# 2021-03-12 04:20:28.620Z INFO      - m034h:    -55.724 ns,    -97.52 samples
#
# 2021-03-12 04:20:28.621Z INFO      - m034v:    -55.656 ns,    -97.40 samples
#
# 2021-03-12 04:20:28.621Z INFO      - m035h:    -26.449 ns,    -46.29 samples
#
# 2021-03-12 04:20:28.622Z INFO      - m035v:    -26.562 ns,    -46.48 samples
#
# 2021-03-12 04:20:28.623Z INFO      - m038h:    -34.512 ns,    -60.40 samples
#
# 2021-03-12 04:20:28.623Z INFO      - m038v:    -34.454 ns,    -60.30 samples
#
# 2021-03-12 04:20:28.624Z INFO      - m043h:     19.936 ns,     34.89 samples
#
# 2021-03-12 04:20:28.624Z INFO      - m043v:     20.019 ns,     35.03 samples
#
# 2021-03-12 04:20:28.625Z INFO      - m045h:    -53.964 ns,    -94.44 samples
#
# 2021-03-12 04:20:28.625Z INFO      - m045v:    -54.098 ns,    -94.67 samples
#
# 2021-03-12 04:20:28.626Z INFO      - m048h:    192.989 ns,    337.73 samples
#
# 2021-03-12 04:20:28.627Z INFO      - m048v:   -115.494 ns,   -202.11 samples
#
# 2021-03-12 04:20:28.627Z INFO      - m049h:   -118.219 ns,   -206.88 samples
#
# 2021-03-12 04:20:28.628Z INFO      - m049v:   -118.249 ns,   -206.94 samples
#
# 2021-03-12 04:20:28.628Z INFO      - m050h:      8.836 ns,     15.46 samples
#
# 2021-03-12 04:20:28.629Z INFO      - m050v:      8.787 ns,     15.38 samples
#
# 2021-03-12 04:20:28.629Z INFO      - m053h:    -25.303 ns,    -44.28 samples
#
# 2021-03-12 04:20:28.630Z INFO      - m053v:    -25.331 ns,    -44.33 samples
#
# 2021-03-12 04:20:28.630Z INFO      - m054h:    -44.128 ns,    -77.22 samples
#
# 2021-03-12 04:20:28.631Z INFO      - m054v:    -44.166 ns,    -77.29 samples
#
# 2021-03-12 04:20:28.631Z INFO      - m056h:    -15.732 ns,    -27.53 samples
#
# 2021-03-12 04:20:28.632Z INFO      - m056v:    -15.677 ns,    -27.43 samples
#
# 2021-03-12 04:20:28.632Z INFO      - m057h:    -25.682 ns,    -44.94 samples
#
# 2021-03-12 04:20:28.633Z INFO      - m057v:    -25.834 ns,    -45.21 samples
#
# 2021-03-12 04:20:28.633Z INFO      - m059h:    -23.140 ns,    -40.50 samples
#
# 2021-03-12 04:20:28.634Z INFO      - m059v:    -23.184 ns,    -40.57 samples
#
# 2021-03-12 04:20:28.634Z INFO      - m060h:    -89.918 ns,   -157.36 samples
#
# 2021-03-12 04:20:28.635Z INFO      - m060v:    -90.005 ns,   -157.51 samples
#
# 2021-03-12 04:20:28.635Z INFO      - m061h:      0.000 ns,      0.00 samples
#
# 2021-03-12 04:20:28.636Z INFO      - m061v:      0.065 ns,      0.11 samples
#
# 2021-03-12 04:20:28.636Z INFO      - m063h:    -38.599 ns,    -67.55 samples
#
# 2021-03-12 04:20:28.637Z INFO      - m063v:    -38.635 ns,    -67.61 samples

# %%
x #delays in *ns* per receptor per pol
#import numpy as np
#np.shape(x)

new_x=[]
steps=range(0, len(x), 4)
for step in steps:
    print(step, x[step][:-2], x[step+1], x[step+3])
    if abs((x[step+1])-(x[step+3])) > 1: #if the difference is more than 1ns we don't like it
        print('*Bad delay cal*\n')
    else:
        new_x+=x[step][:-2], x[step+1]/refrac, x[step+3]/refrac
        #this is calculated delay in meters
        #guessing negative means shorter and positive means longer
# Out:
# 0 m001 -36.221 -36.228
# 4 m002 -21.362 -21.36
# 8 m003 -52.035 -52.055
# 12 m004 -70.615 -70.658
# 16 m005 -71.386 -71.436
# 20 m006 -92.685 -92.771
# 24 m007 -48.502 -48.178
# 28 m008 -62.115 -61.877
# 32 m009 -41.155 -41.19
# 36 m010 -82.585 -82.658
# 40 m011 -28.259 -28.345
# 44 m012 -56.575 -56.454
# 48 m013 -97.056 -96.96
# 52 m014 -267.626 -267.66
# 56 m017 -328.832 -328.852
# 60 m018 1720.758 1092.792
# *Bad delay cal*
#
# 64 m019 -59.785 -59.798
# 68 m020 -33.008 -33.054
# 72 m021 -103.355 -103.448
# 76 m022 -12.893 -12.944
# 80 m023 -7.452 -7.44
# 84 m027 -57.797 -57.737
# 88 m030 -74.875 -74.824
# 92 m032 -70.046 -70.008
# 96 m034 -55.724 -55.656
# 100 m035 -26.449 -26.562
# 104 m038 -34.512 -34.454
# 108 m043 19.936 20.019
# 112 m045 -53.964 -54.098
# 116 m048 192.989 -115.494
# *Bad delay cal*
#
# 120 m049 -118.219 -118.249
# 124 m050 8.836 8.787
# 128 m053 -25.303 -25.331
# 132 m054 -44.128 -44.166
# 136 m056 -15.732 -15.677
# 140 m057 -25.682 -25.834
# 144 m059 -23.14 -23.184
# 148 m060 -89.918 -90.005
# 152 m061 0.0 0.065
# 156 m063 -38.599 -38.635

# %%
#new_x
receptors=[]
new_range=range(0, len(new_x), 3)
for i in new_range:
    print('{} {:.4f} {:.4f}'.format(new_x[i], new_x[i+1], new_x[i+2]))
    receptor=new_x[i]
    f=open('/home/pkotze/checkouts/katconfig/user/delay-models/mkat/'+receptor+'_'+band+'.txt')
    fw=open('/home/pkotze/checkouts/python/output/'+receptor+'_'+band+'.txt','w')
    line=f.readline()
    ll=line.split(' ') #ll means list of the line read as a str
    print('Old: ', line.strip('\n'))

    new_linestr = '{} {} {} {:.4f} {:.4f} {}'.format(ll[0], ll[1], ll[2], float(ll[3])+new_x[i+1], float(ll[4])+new_x[i+2],ll[5])
    print('New: ', new_linestr)
    fw.write(new_linestr)
    f.close()
    fw.close()
# Out:
# m001 -7.6015 -7.6029
# Old:  1.1205 -171.762 8.4705 209.996 209.996 1
# New:  1.1205 -171.762 8.4705 202.3945 202.3931 1
#
# m002 -4.4831 -4.4827
# Old:  -32.113 -224.236 8.6445 211.7145 211.7145 1
# New:  -32.113 -224.236 8.6445 207.2314 207.2318 1
#
# m003 -10.9203 -10.9244
# Old:  -66.518 -202.276 8.285 213.4215 213.4215 1
# New:  -66.518 -202.276 8.285 202.5012 202.4971 1
#
# m004 -14.8195 -14.8285
# Old:  -123.624 -252.946 8.513 210.42 210.42 1
# New:  -123.624 -252.946 8.513 195.6005 195.5915 1
#
# m005 -14.9813 -14.9918
# Old:  -102.088 -283.12 8.875 217.998 217.998 1
# New:  -102.088 -283.12 8.875 203.0167 203.0062 1
#
# m006 -19.4512 -19.4693
# Old:  -18.2315 -295.428 9.188 220.4 220.4 1
# New:  -18.2315 -295.428 9.188 200.9488 200.9307 1
#
# m007 -10.1788 -10.1108
# Old:  -89.592 -402.732 9.7685 205.53 205.53 1
# New:  -89.592 -402.732 9.7685 195.3512 195.4192 1
#
# m008 -13.0357 -12.9857
# Old:  -93.527 -535.026 10.4445 215.5085 215.5085 1
# New:  -93.527 -535.026 10.4445 202.4728 202.5228 1
#
# m009 -8.6369 -8.6443
# Old:  32.3565 -371.0555 10.14 191.0535 191.0535 1
# New:  32.3565 -371.0555 10.14 182.4166 182.4092 1
#
# m010 -17.3316 -17.3469
# Old:  88.095 -511.872 11.1855 221.4135 221.4135 1
# New:  88.095 -511.872 11.1855 204.0819 204.0666 1
#
# m011 -5.9305 -5.9486
# Old:  84.0115 -352.078 10.151 198.1045 198.1045 1
# New:  84.0115 -352.078 10.151 192.1740 192.1559 1
#
# m012 -11.8730 -11.8476
# Old:  140.019 -368.267 10.4485 203.253 203.253 1
# New:  140.019 -368.267 10.4485 191.3800 191.4054 1
#
# m013 -20.3685 -20.3484
# Old:  236.7915 -393.46 11.124 204.152 204.152 1
# New:  236.7915 -393.46 11.124 183.7835 183.8036 1
#
# m014 -56.1650 -56.1721
# Old:  280.669 -285.792 10.5465 207.289 207.289 1
# New:  280.669 -285.792 10.5465 151.1240 151.1169 1
#
# m017 -69.0099 -69.0141
# Old:  199.6235 -112.263 8.9545 209.365 209.365 1
# New:  199.6235 -112.263 8.9545 140.3551 140.3509 1
#
# m019 -12.5467 -12.5494
# Old:  170.7865 -285.223 10.0705 199.8325 199.8325 1
# New:  170.7865 -285.223 10.0705 187.2858 187.2831 1
#
# m020 -6.9272 -6.9368
# Old:  97.016 -299.638 9.8765 170.9565 170.9565 1
# New:  97.016 -299.638 9.8765 164.0293 164.0197 1
#
# m021 -21.6905 -21.7100
# Old:  -295.9655 -327.241 8.117 204.887 204.887 1
# New:  -295.9655 -327.241 8.117 183.1965 183.1770 1
#
# m022 -2.7058 -2.7165
# Old:  -373.0015 0.544 5.649 208.6425 208.6425 1
# New:  -373.0015 0.544 5.649 205.9367 205.9260 1
#
# m023 -1.5639 -1.5614
# Old:  -322.306 -142.1845 6.8245 205.15 205.15 1
# New:  -322.306 -142.1845 6.8245 203.5861 203.5886 1
#
# m027 -12.1295 -12.1169
# Old:  40.4745 -23.112 7.694 198.656 198.656 1
# New:  40.4745 -23.112 7.694 186.5265 186.5391 1
#
# m030 -15.7135 -15.7028
# Old:  171.2805 113.949 7.278 200.3155 200.3155 1
# New:  171.2805 113.949 7.278 184.6020 184.6127 1
#
# m032 -14.7001 -14.6921
# Old:  461.2745 175.505 7.367 199.8455 199.8455 1
# New:  461.2745 175.505 7.367 185.1454 185.1534 1
#
# m034 -11.6944 -11.6802
# Old:  357.8105 -28.308 8.972 198.083 198.083 1
# New:  357.8105 -28.308 8.972 186.3886 186.4028 1
#
# m035 -5.5507 -5.5744
# Old:  386.152 -180.8935 10.2895 190.053 190.053 1
# New:  386.152 -180.8935 10.2895 184.5023 184.4786 1
#
# m038 -7.2428 -7.2306
# Old:  213.308 -569.08 11.946 209.1945 209.1945 1
# New:  213.308 -569.08 11.946 201.9517 201.9639 1
#
# m043 4.1838 4.2013
# Old:  -629.8525 -128.326 5.264 191.7415 191.7415 1
# New:  -629.8525 -128.326 5.264 195.9253 195.9428 1
#
# m045 -11.3251 -11.3532
# Old:  -1832.8595 266.75 0.1075 213.253 213.253 1
# New:  -1832.8595 266.75 0.1075 201.9279 201.8998 1
#
# m049 -24.8099 -24.8162
# Old:  -3605.9565 436.462 2.696 217.607 217.607 1
# New:  -3605.9565 436.462 2.696 192.7971 192.7908 1
#
# m050 1.8544 1.8441
# Old:  -2052.336 -843.7145 5.3375 221.334 221.334 1
# New:  -2052.336 -843.7145 5.3375 223.1884 223.1781 1
#
# m053 -5.3102 -5.3161
# Old:  9.3645 -1304.462 15.032 212.7925 212.7925 1
# New:  9.3645 -1304.462 15.032 207.4823 207.4764 1
#
# m054 -9.2609 -9.2688
# Old:  871.9795 -499.812 13.3635 214.734 214.734 1
# New:  871.9795 -499.812 13.3635 205.4731 205.4652 1
#
# m056 -3.3016 -3.2900
# Old:  1598.4025 466.6675 6.99 185.6005 185.6005 1
# New:  1598.4025 466.6675 6.99 182.2989 182.3105 1
#
# m057 -5.3897 -5.4216
# Old:  294.6445 3259.9145 -10.6365 189.3455 189.3455 1
# New:  294.6445 3259.9145 -10.6365 183.9558 183.9239 1
#
# m059 -4.8562 -4.8655
# Old:  3686.4265 758.895 11.8215 199.4575 199.4575 1
# New:  3686.4265 758.895 11.8215 194.6013 194.5920 1
#
# m060 -18.8705 -18.8888
# Old:  3419.6825 -1840.478 23.6965 211.459 211.459 1
# New:  3419.6825 -1840.478 23.6965 192.5885 192.5702 1
#
# m061 0.0000 0.0136
# Old:  -16.4085 -2323.779 21.304 207.6255 207.6255 1
# New:  -16.4085 -2323.779 21.304 207.6255 207.6391 1
#
# m063 -8.1005 -8.1081
# Old:  -3419.5845 -1840.48 16.3825 16.171 16.171 1
# New:  -3419.5845 -1840.48 16.3825 8.0705 8.0629 1

# %%
print(receptors)

#only showing delay cal model for the following bands
bands=['s']
for receptor in receptors:
    print(receptor+'....====>')
    for band in bands:
        print(receptor+'_'+band+'.txt')
        f=open('/home/pkotze/checkouts/katconfig/user/delay-models/mkat/'+receptor+'_'+band+'.txt')
        lines=f.readlines()
        float(lines.split('')[3])
        f.close()
        print(lines)
# Out:
# []
